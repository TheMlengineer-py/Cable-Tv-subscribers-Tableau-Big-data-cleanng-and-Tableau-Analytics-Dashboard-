# %% [markdown]
# # CableTVSubscribersData preprocessing

# %%
#Read CSV File
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_csv('CableTVSubscribersData.csv')
Cable_tv_subscribers=df
Cable_tv_subscribers
# Out:
#            age  gender        income  kids ownHome subscribe     Segment
# 0    47.316133    Male  49482.810438     2   ownNo     subNo  Suburb mix
# 1    31.386839    Male  35546.288300     1  ownYes     subNo  Suburb mix
# 2    43.200342    Male  44169.186377     0  ownYes     subNo  Suburb mix
# 3    37.316995  Female  81041.986385     1   ownNo     subNo  Suburb mix
# 4    40.954390  Female  79353.014443     3  ownYes     subNo  Suburb mix
# ..         ...     ...           ...   ...     ...       ...         ...
# 295  32.952269  Female  43882.425614     0  ownYes     subNo   Moving up
# 296  40.962547  Female  64197.086875     2   ownNo     subNo   Moving up
# 297  38.229804    Male  47580.926777     0   ownNo    subYes   Moving up
# 298  33.170364    Male  60747.336395     1   ownNo     subNo   Moving up
# 299  34.383878    Male  53674.931370     5  ownYes     subNo   Moving up
#
# [300 rows x 7 columns]

# %%
#create function to check for missing values in the data

def count_of_null(Cable_tv_subscribers):
    count=Cable_tv_subscribers.isnull().sum().sum()
    return count

# print missing value count in the data
count_null = count_of_null(Cable_tv_subscribers)
print(count_null)
# Out:
# 0

# %%
#create function to check duplicate values in the data
def check_duplicates(Cable_tv_subscribers):
    count=Cable_tv_subscribers.duplicated().sum().sum()
    return count

# print duplicate values in the data
count_duplicates = check_duplicates(Cable_tv_subscribers)
print(count_duplicates)
# Out:
# 0

# %%
#create a function to check information about the data
def about_data (Cable_tv_subscribers):
        about=Cable_tv_subscribers.info()
        return about
    
#print information about the data
info=about_data (Cable_tv_subscribers)
print(info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        300 non-null    float64
#  1   gender     300 non-null    object
#  2   income     300 non-null    float64
#  3   kids       300 non-null    int64
#  4   ownHome    300 non-null    object
#  5   subscribe  300 non-null    object
#  6   Segment    300 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 16.5+ KB
# None

# %%
# Convert the age column to integer
Cable_tv_subscribers['age'] = Cable_tv_subscribers['age'].astype(int)

# Print the updated DataFrame
Cable_tv_subscribers
# Out:
#      age  gender        income  kids ownHome subscribe     Segment
# 0     47    Male  49482.810438     2   ownNo     subNo  Suburb mix
# 1     31    Male  35546.288300     1  ownYes     subNo  Suburb mix
# 2     43    Male  44169.186377     0  ownYes     subNo  Suburb mix
# 3     37  Female  81041.986385     1   ownNo     subNo  Suburb mix
# 4     40  Female  79353.014443     3  ownYes     subNo  Suburb mix
# ..   ...     ...           ...   ...     ...       ...         ...
# 295   32  Female  43882.425614     0  ownYes     subNo   Moving up
# 296   40  Female  64197.086875     2   ownNo     subNo   Moving up
# 297   38    Male  47580.926777     0   ownNo    subYes   Moving up
# 298   33    Male  60747.336395     1   ownNo     subNo   Moving up
# 299   34    Male  53674.931370     5  ownYes     subNo   Moving up
#
# [300 rows x 7 columns]

# %%
# create function to print unique values in the dataframe

def print_unique_values(Cable_tv_subscribers):
    for column in Cable_tv_subscribers.columns:
        unique_values = Cable_tv_subscribers[column].unique()
        print(f"Column '{column}' has {len(unique_values)} unique values:")
        print(unique_values)
print_unique_values(Cable_tv_subscribers)
# Out:
# Column 'age' has 54 unique values:
# [47 31 43 37 40 28 44 35 33 39 42 41 32 36 30 38 26 53 45 34 29 49 46 48
#  24 23 21 22 20 25 27 19 56 64 57 68 66 75 60 52 55 51 65 62 50 70 58 61
#  63 59 54 71 78 80]
# Column 'gender' has 2 unique values:
# ['Male' 'Female']
# Column 'income' has 300 unique values:
# [ 49482.8104378   35546.28830014  44169.18637677  81041.98638534
#   79353.01444282  58143.36332204  19282.23062193  47245.2384701
#   48332.51977193  52567.89025768  47917.56323589  65767.47829225
#   69337.65630432  57200.14564119  47099.7735756   57036.83733014
#   53127.0588275   41254.80429131  63528.47494962  52649.53718363
#   48197.80834589  46163.38331881  44151.93088858  56128.00883602
#   62519.89078701  51195.96837832  59440.87407194  57362.59022179
#   56112.12278324  76488.69967154  65717.43073259  45175.35617678
#   49943.11842143  60040.79190431  65169.57719184  46765.31053819
#   61291.8146655   49392.66993516  30769.55074676  59804.93270581
# ...

# %%
#Create function to check statistical summary of the dataset
def stat_summary (Cable_tv_subscribers):
    statistics_sum = Cable_tv_subscribers.describe()
    return statistics_sum
#print statistical summary of data
summary = stat_summary (Cable_tv_subscribers)
summary
# Out:
#               age         income        kids
# count  300.000000     300.000000  300.000000
# mean    40.720000   50936.536184    1.270000
# std     12.723517   20137.549430    1.408443
# min     19.000000   -5183.354243    0.000000
# 25%     32.750000   39656.283622    0.000000
# 50%     39.000000   52014.352449    1.000000
# 75%     47.000000   61403.176264    2.000000
# max     80.000000  114278.255567    7.000000

# %%
#create function to find columns with Categorical Values

def categorcal_columns (Cable_tv_subscribers):
    cat_cols= Cable_tv_subscribers.select_dtypes(exclude=['int','float']).columns.tolist()
    return cat_cols
#print categorical columns
categorical = categorcal_columns (Cable_tv_subscribers)
categorical
# Out:
# ['gender', 'ownHome', 'subscribe', 'Segment']

# %%
#create function to find columns with Numerical Values

def numerical_columns (Cable_tv_subscribers):
    num_cols = Cable_tv_subscribers.select_dtypes(include=['int','float']).columns.tolist()
    return num_cols
#print numerical columns
numerical = numerical_columns (Cable_tv_subscribers)
numerical
# Out:
# ['age', 'income', 'kids']

# %%
#Removing extra spaces from the features Using strip()
Cable_tv_subscribers.columns = Cable_tv_subscribers.columns.str.strip()

# %%
#Finding Outliers using IQR score

#The IQR is the first quartile subtracted from the third quartile; 
#these quartiles can be clearly seen on a box plot on the data.
# calculate IQR score
Q1 = Cable_tv_subscribers.quantile(0.25)
Q3 = Cable_tv_subscribers.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# IQR of each column
# Out:
# age          14.250000
# income    21746.892642
# kids          2.000000
# dtype: float64

# %%
#remove outlier
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

Cable_tv_subscribers = Cable_tv_subscribers[~((Cable_tv_subscribers < (Q1 - 1.5 * IQR)) |(Cable_tv_subscribers > (Q3 + 1.5 * IQR))).any(axis=1)]
Cable_tv_subscribers.shape
# Out:
# (281, 7)

# %%
# load cleaned Cable_tv_subscribers dataframe into CSV file.
Cable_tv_subscribers.to_csv('Fixed_Cable_tv_subscribers_data.csv', index=False, header=True)

# %% [markdown]
# # Churn Data preprocessing

# %%
df=pd.read_csv('churned_clean_.csv')
churn=df
churn
# Out:
#       Unnamed: 0  CaseOrder Customer_id                           Interaction  \
# 0              0          1     K409198  aa90260b-4141-4a24-8e36-b04ce1f4f77b
# 1              1          2     S120509  fb76459f-c047-4a9d-8af9-e0f7d4ac2524
# 2              2          3     K191035  344d114c-3736-4be5-98f7-c72c281e2d35
# 3              3          4      D90850  abfa2b40-2d43-4994-b15a-989b8c79e311
# 4              4          5     K662701  68a861fd-0d20-4e51-a587-8a90407ee574
# ...          ...        ...         ...                                   ...
# 9995        9995       9996     M324793  45deb5a2-ae04-4518-bf0b-c82db8dbe4a4
# 9996        9996       9997     D861732  6e96b921-0c09-4993-bbda-a1ac6411061a
# 9997        9997       9998     I243405  e8307ddf-9a01-4fff-bc59-4742e03fd24f
# 9998        9998       9999     I641617  3775ccfc-0052-4107-81ae-9657f81ecdf3
# 9999        9999      10000      T38070  9de5fb6e-bd33-4995-aec8-f01d0172a499
#
# ...

# %%
#create function to check for missing values in the data

def count_of_null(churn):
    count=churn.isnull().sum().sum()
    return count

# print missing value count in the data
count_null = count_of_null(churn)
print(count_null)
# Out:
# 0

# %%
#create function to check duplicate values in the data
def check_duplicates(churn):
    count=churn.duplicated().sum().sum()
    return count

# print duplicate values in the data
count_duplicates = check_duplicates(churn)
print(count_duplicates)
# Out:
# 0

# %%
#create a function to check information about the data
def about_data (churn):
        about=churn.info()
        return about
    
#print information about the data
info=about_data (churn)
print(info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 51 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10000 non-null  int64
#  1   CaseOrder             10000 non-null  int64
#  2   Customer_id           10000 non-null  object
#  3   Interaction           10000 non-null  object
#  4   UID                   10000 non-null  object
#  5   City                  10000 non-null  object
#  6   State                 10000 non-null  object
#  7   County                10000 non-null  object
#  8   Zip                   10000 non-null  int64
#  9   Lat                   10000 non-null  float64
#  10  Lng                   10000 non-null  float64
#  11  Population            10000 non-null  int64
#  12  Area                  10000 non-null  object
#  13  TimeZone              10000 non-null  object
#  14  Job                   10000 non-null  object
# ...

# %%
#Remove irrelevant columns

churn=churn.drop(columns=['Item1','Item2','Item3','Item4','Item5','Item6','Item7','Item8','Interaction',
                          'UID', 'City', 'County','TimeZone','CaseOrder','Zip', 'Unnamed: 0',])
churn
# Out:
#      Customer_id State       Lat        Lng  Population      Area  \
# 0        K409198    AK  56.25100 -133.37571          38     Urban
# 1        S120509    MI  44.32893  -84.24080       10446     Urban
# 2        K191035    OR  45.35589 -123.24657        3735     Urban
# 3         D90850    CA  32.96687 -117.24798       13863  Suburban
# 4        K662701    TX  29.38012  -95.80673       11352  Suburban
# ...          ...   ...       ...        ...         ...       ...
# 9995     M324793    VT  43.43391  -72.78734         640     Rural
# 9996     D861732    TN  36.56907  -87.41694       77168     Rural
# 9997     I243405    TX  35.52039 -100.44180         406     Rural
# 9998     I641617    GA  33.58016  -85.13241       35575     Urban
# 9999      T38070    GA  34.70783  -83.53648       12230     Urban
#
#                                     Job  Children  Age    Income  ...  \
# 0     Environmental health practitioner         0   68  28561.99  ...
# ...

# %%
# create function to print unique values in the dataframe

def print_unique_values(churn):
    for column in churn.columns:
        unique_values = churn[column].unique()
        print(f"Column '{column}' has {len(unique_values)} unique values:")
        print(unique_values)
print_unique_values(churn)
# Out:
# Column 'Customer_id' has 10000 unique values:
# ['K409198' 'S120509' 'K191035' ... 'I243405' 'I641617' 'T38070']
# Column 'State' has 52 unique values:
# ['AK' 'MI' 'OR' 'CA' 'TX' 'GA' 'TN' 'OK' 'FL' 'OH' 'PA' 'PR' 'IA' 'ME'
#  'IL' 'WI' 'NC' 'AL' 'NM' 'VT' 'MD' 'NY' 'WA' 'CT' 'NJ' 'DC' 'ND' 'LA'
#  'NE' 'WV' 'AZ' 'MO' 'WY' 'MT' 'VA' 'KY' 'MN' 'KS' 'MA' 'IN' 'SC' 'NH'
#  'DE' 'MS' 'ID' 'AR' 'SD' 'CO' 'HI' 'UT' 'RI' 'NV']
# Column 'Lat' has 8563 unique values:
# [56.251   44.32893 45.35589 ... 43.43391 36.56907 34.70783]
# Column 'Lng' has 8630 unique values:
# [-133.37571  -84.2408  -123.24657 ...  -72.78734  -87.41694  -83.53648]
# Column 'Population' has 5933 unique values:
# [   38 10446  3735 ...  4261 77168 12230]
# Column 'Area' has 3 unique values:
# ['Urban' 'Suburban' 'Rural']
# Column 'Job' has 639 unique values:
# ['Environmental health practitioner' 'Programmer, multimedia'
#  'Chief Financial Officer' 'Solicitor' 'Medical illustrator'
# ...

# %%
#Create function to check statistical summary of the dataset
def stat_summary (churn):
    statistics_sum = churn.describe()
    return statistics_sum
#print statistical summary of data
summary = stat_summary (churn)
summary
# Out:
#                 Lat           Lng     Population    Children           Age  \
# count  10000.000000  10000.000000   10000.000000  10000.0000  10000.000000
# mean      38.757567    -90.782536    9756.562400      2.0877     53.078400
# std        5.437389     15.156142   14432.698671      2.1472     20.698882
# min       17.966120   -171.688150       0.000000      0.0000     18.000000
# 25%       35.341828    -97.082812     738.000000      0.0000     35.000000
# 50%       39.395800    -87.918800    2910.500000      1.0000     53.000000
# 75%       42.106908    -80.088745   13168.000000      3.0000     71.000000
# max       70.640660    -65.667850  111850.000000     10.0000     89.000000
#
#               Income  Outage_sec_perweek         Email      Contacts  \
# count   10000.000000        10000.000000  10000.000000  10000.000000
# mean    39806.926771           10.001848     12.016000      0.994200
# std     28199.916702            2.976019      3.025898      0.988466
# ...

# %%
#create function to find columns with Categorical Values

def categorcal_columns (churn):
    cat_cols= churn.select_dtypes(exclude=['int','float']).columns.tolist()
    return cat_cols
#print categorical columns
categorical = categorcal_columns (churn)
categorical
# Out:
# ['Customer_id',
#  'State',
#  'Area',
#  'Job',
#  'Marital',
#  'Gender',
#  'Churn',
#  'Techie',
#  'Contract',
#  'Port_modem',
#  'Tablet',
#  'InternetService',
#  'Phone',
#  'Multiple',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
#create function to find columns with Numerical Values

def numerical_columns (churn):
    num_cols = churn.select_dtypes(include=['int','float']).columns.tolist()
    return num_cols
#print numerical columns
numerical = numerical_columns (churn)
numerical
# Out:
# ['Lat',
#  'Lng',
#  'Population',
#  'Children',
#  'Age',
#  'Income',
#  'Outage_sec_perweek',
#  'Email',
#  'Contacts',
#  'Yearly_equip_failure',
#  'Tenure',
#  'MonthlyCharge',
#  'Bandwidth_GB_Year']

# %%
#Removing extra spaces from the features Using strip()
churn.columns = churn.columns.str.strip()

# %%
#Finding Outliers using IQR score

#The IQR is the first quartile subtracted from the third quartile; 
#these quartiles can be clearly seen on a box plot on the data.
# calculate IQR score
#where Q3 is the 75th percentile of the data and Q1 is the 25th percentile of the data.
Q1 = churn.quantile(0.25)
Q3 = churn.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# IQR of each column
# Out:
# Lat                         6.765080
# Lng                        16.994067
# Population              12430.000000
# Children                    3.000000
# Age                        36.000000
# Income                  34021.452500
# Outage_sec_perweek          3.951271
# Email                       4.000000
# Contacts                    2.000000
# Yearly_equip_failure        1.000000
# Tenure                     53.562101
# MonthlyCharge              60.755486
# Bandwidth_GB_Year        4349.670543
# dtype: float64

# %%
#remove outlier
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)
#Once the IQR is calculated, we can use it to identify outliers by defining a threshold range as follows;
#Lower threshold = Q1 - 1.5 * IQR
#Upper threshold = Q3 + 1.5 * IQR
#Any data points that fall outside of this range are considered outliers and removed from the dataset

churn = churn[~((churn < (Q1 - 1.5 * IQR)) |(churn > (Q3 + 1.5 * IQR))).any(axis=1)]
churn.shape
# Out:
# (7973, 35)

# %%
# load cleaned churn dataframe into CSV file.
churn.to_csv('Fixed_churn.csv', index=False, header=True)

# %% [markdown]
# # Create MySQL Database

# %%
#create a database in MySQL, using the "CREATE DATABASE" statement
import mysql.connector

#mydb = mysql.connector.connect(
  #host="###.#.#.#",
  #user="####",
  #password="#####"
#)

#mycursor = mydb.cursor()

#mycursor.execute("CREATE DATABASE cable_subscribers")  # set database name

# %%
#check if a database exist by listing all databases in the system using the "SHOW DATABASES" statement:
#mydb = mysql.connector.connect(
  #host="###.#.#.#",
  #user="####",
  #password="Agronomy7@"
#)

#mycursor = mydb.cursor()

#mycursor.execute("SHOW DATABASES")

#for x in mycursor:
    #print(x)
